# %% [markdown]
# ## The fist day

# %%
import pandas as pd

# %%
df =pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head() #  for big data
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# for hows the data look like

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 434          435         0       1
# 167          168         0       3
# 499          500         0       3
# 341          342         1       1
# 698          699         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 434                        Silvey, Mr. William Baird    male  50.0      1
# 167  Skoog, Mrs. William (Anna Bernhardina Karlsson)  female  45.0      1
# 499                               Svensson, Mr. Olof    male  24.0      0
# 341                   Fortune, Miss. Alice Elizabeth  female  24.0      3
# 698                         Thayer, Mr. John Borland    male  49.0      1
#
#      Parch  Ticket      Fare        Cabin Embarked
# 434      0   13507   55.9000          E44        S
# 167      4  347088   27.9000          NaN        S
# 499      0  350035    7.7958          NaN        S
# 341      2   19950  263.0000  C23 C25 C27        S
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# 0

# %%
numeric_type =df.select_dtypes(include=['number'])
correlation = numeric_type.corr()
print(correlation)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## countplot

# %%
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(df['Age'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Age'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Age'>

# %%
## pie chart

# %%
df['Age'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Embarked'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Embarked'].value_counts().plot(kind = 'pie' ,autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
### numerical data agya ab

# %%
## HIstogram 
import matplotlib.pyplot as plt
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt 
plt.hist(df['Survived'],bins = 5)
# Out:
# (array([549.,   0.,   0.,   0., 342.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <BarContainer object of 5 artists>)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Survived'],bins =5)
# Out:
# (array([549.,   0.,   0.,   0., 342.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
# histogram exact numver batat hai ky us range may kitny numbers hain whereas the
# displot tells us the probability of the function

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13544\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(df['Survived'])

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13544\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
## Box Plot  to deals with the numerical data we use box plot  and they give 5 numbers summary

# %%
## agr koi  value apky calcualted minimum and calculated maximum sy bahir hai to ya hai potiential outliers jo hmaray noraml data ko follow nhi krtty

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.boxplot(df['Sex'])
# Out:
# <Axes: ylabel='Sex'>

# %%
sns.boxplot(df['Survived'])
# Out:
# <Axes: ylabel='Survived'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Survived'].max()
# Out:
# 1

# %%
df['Survived'].mean()
# Out:
# 0.3838383838383838

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704
